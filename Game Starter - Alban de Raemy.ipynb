# %% [markdown]
# # Game Assignment Starter Code
#
# The purpose of this code is to demonstrate how to construct a structure based on a game map. In this starter code, we will assume that we have three rooms on our game map. The assignment requirements also specify that we have a fail function. Therefore, we will be creating a simple skeleton containing the following elements:
# * room_1
# * room_2
# * room_3
# * fail
#
# Our map can be visualized as follows:
# <br><br>
#
# ~~~
#     room_1 --> room_2 --> room_3 (win)
#             |          |
#              `----------`------> fail
# ~~~
#
# <br>
#
# ## Part 1: Building up one room at a time (no fail function)

# %%
#########################################################
# Constructing lab and calling it to start the game
#########################################################

# Setup
#Import necessary packages
from sys import exit # check this one
import random
import time
import sys


#################################
# Def the Starting room function#
#################################

def lab():
    
    
    #Global variables that will be used in different rooms
    global name
    global german_city
    global strong_animal
    global german_name
    
    #Introduction
    print("""\nWelcome to Der Riese, the Game!
Before we start I need you to answer a few questions...""")
    
    #############
    #Questions##
    ############
    name = input("What is your last name?\n") #user input that will be used as the user's name
    name = name.capitalize() # capitalize first letter of user's input
    print(f"Welcome Dr.{name}!\n")
    time.sleep(.8) # creating a 0.8 seconde break
    
    german_city = input("What's your favorite german city? Feel free to make up a german city name if you can't think of one.\n ")
    german_city = german_city.capitalize() 
        
    strong_animal = input("What's the name of the strongest animal you can think of?\n")
    print("Interesting pick.. I have one more question.\n")
          
    german_name = input("Please make up a german sounding last name:\n")
    german_name = german_name.capitalize() # capitalize first letter of user's input
    print(f"{german_name}! That's a great name, but I'm glad it's not mine ;)\n")
    time.sleep(1)
          
    
    
    #Story Intro
    input("Press Enter to start...\n")
    print("Congrats, Dr. " + name + "!")
    time.sleep(1)
    print(f"""You were hired by the CIA to work in {german_city}, Germany at the Der Riese top secret facility.
The facility was created by Dr. {german_name} after discovering the element 115 in a meteorite.
This element has interesting capabilites that seem to give extra strength to humans.
The team of scientists has already developed a mixture that limits pain and help faster recovery.
They named it the {strong_animal} soda.""")
    time.sleep(9)
          
    # Create a dashed line
    dashed_line = 0
    while dashed_line < 50:
        print('-', end="")# Print the dashes on the same line
        dashed_line += 1
        time.sleep(.03)
        
    time.sleep(1.5) 

    print("\nA few months into your new job, you're by yourself late at night working on your project...")
    time.sleep(2)

    # Start of the Game
    input("Suddenly, an alarm goes off! Press Enter to continue.\n")
    time.sleep(1.5)
          
    print("It's a code red!\n")
    time.sleep(1)
    
    # First choice
    print("What should you do?\n")
    time.sleep(1)
    
    #Options in the lab
    print("Press 1 to panic and run towards an exit.")
    print("Press 2 to take some time to explore your lab.")
          
    choice_1 = input("> ")
    
          
    # conditional input based on user input    
    if choice_1 == '1':
        fail_1()

    elif choice_1 == '2':
        explore() # this makes us explore our lab
    
    else:
        print("Invalid entry. Please try again.\n")
        lab() # Brings us back to the beginning of the lab to try again
    
lab() # This starts the game

# %% [markdown]
# ***

# %%
#########################################################
# Adding explore and linking it to lab
#########################################################

# Setup
#Import necessary packages
from sys import exit # check this one
import random
import time
import sys


#################################
# Def the Starting room function#
#################################

def lab():
    
    
    #Global variables that will be used in different rooms
    global name
    global german_city
    global strong_animal
    global german_name
    
    #Introduction
    print("""\nWelcome to Der Riese, the Game!
Before we start I need you to answer a few questions...""")
    
    #############
    #Questions##
    ############
    name = input("What is your last name?\n") #user input that will be used as the user's name
    name = name.capitalize() # capitalize first letter of user's input
    print(f"Welcome Dr.{name}!\n")
    time.sleep(.8) # creating a 0.8 seconde break
    
    german_city = input("What's your favorite german city? Feel free to make up a german city name if you can't think of one.\n ")
    german_city = german_city.capitalize() 
        
    strong_animal = input("What's the name of the strongest animal you can think of?\n")
    print("Interesting pick.. I have one more question.\n")
          
    german_name = input("Please make up a german sounding last name:\n")
    german_name = german_name.capitalize() # capitalize first letter of user's input
    print(f"{german_name}! That's a great name, but I'm glad it's not mine ;)\n")
    time.sleep(1)
          
    
    
    #Story Intro
    input("Press Enter to start...\n")
    print("Congrats, Dr. " + name + "!")
    time.sleep(1)
    print(f"""You were hired by the CIA to work in {german_city}, Germany at the Der Riese top secret facility.
The facility was created by Dr. {german_name} after discovering the element 115 in a meteorite.
This element has interesting capabilites that seem to give extra strength to humans.
The team of scientists has already developed a mixture that limits pain and help faster recovery.
They named it the {strong_animal} soda.""")
    time.sleep(9)
          
    # Create a dashed line
    dashed_line = 0
    while dashed_line < 50:
        print('-', end="")# Print the dashes on the same line
        dashed_line += 1
        time.sleep(.03)
        
    time.sleep(1.5) 

    print("\nA few months into your new job, you're by yourself late at night working on your project...")
    time.sleep(2)

    # Start of the Game
    input("Suddenly, an alarm goes off! Press Enter to continue.\n")
    time.sleep(1.5)
          
    print("It's a code red!\n")
    time.sleep(1)
    
    # First choice
    print("What should you do?\n")
    time.sleep(1)
    
    #Options in the lab
    print("Press 1 to panic and run towards an exit.")
    print("Press 2 to take some time to explore your lab.")
          
    choice_1 = input("> ")
    
          
    # conditional input based on user input    
    if choice_1 == '1':
        fail_1()

    elif choice_1 == '2':
        explore() # this makes us explore our lab
    
    else:
        print("Invalid entry. Please try again.\n")
        lab() # Brings us back to the beginning of the lab to try again
    
          
#############################          
##Action in the first Room###       
#############################          
         
def explore():
    print("You decided to explore your lab...")
    time.sleep(.5)
     
    # Animation similar to a loading wheel while the user searches the lab
    searching = "/-\|" #animation to look like a laoding wheel
    print("Searching the lab:")
    for bars in range(20):
          time.sleep(0.2)
          sys.stdout.write("\r" + searching[bars % len(searching)])
          sys.stdout.flush() # remove what has been printed, to give room for the next part of the wheel

    print("You found a gas mask and knife.")
    time.sleep(1.5)
    print("After putting your gas mask on for safety, it's time to explore\n!")
    time.sleep(1.5)
    print("Where do you want to go?\n")
    time.sleep(1.5)
    
    #Three options from the first rooms
    print("Press 1 to go to the control room to have access to the cameras and security system.")
    print("Press 2 to look for the closest phone to call police.")
    print("Press 3 to go downstairs to the storage room for element 115.")
    
    choice = input("> ")
    
    if choice == '1':
        control_room() # This moves us into the control room

    elif choice == '2':
        fail_2() # This moves us into fail_2
        
    elif choice == '3':
        fail_3() # This moves us into fail_3
        
    
    else:
        print("Invalid entry. Please try again.\n")
        lab() # Brings us back to the beginning of the lab explore to try again

    
lab() # Calling the first function in our map will start our game

# %%
#########################################################
# Adding control_room and linking it to explore
#########################################################


# Setup
#Import necessary packages
from sys import exit # check this one
import random
import time
import sys


#################################
# Def the Starting room function#
#################################

def lab():
    
    
    #Global variables that will be used in different rooms
    global name
    global german_city
    global strong_animal
    global german_name
    
    #Introduction
    print("""\nWelcome to Der Riese, the Game!
Before we start I need you to answer a few questions...""")
    
    #############
    #Questions##
    ############
    name = input("What is your last name?\n") #user input that will be used as the user's name
    name = name.capitalize() # capitalize first letter of user's input
    print(f"Welcome Dr.{name}!\n")
    time.sleep(.8) # creating a 0.8 seconde break
    
    german_city = input("What's your favorite german city? Feel free to make up a german city name if you can't think of one.\n ")
    german_city = german_city.capitalize() 
        
    strong_animal = input("What's the name of the strongest animal you can think of?\n")
    print("Interesting pick.. I have one more question.\n")
          
    german_name = input("Please make up a german sounding last name:\n")
    german_name = german_name.capitalize() # capitalize first letter of user's input
    print(f"{german_name}! That's a great name, but I'm glad it's not mine ;)\n")
    time.sleep(1)
          
    
    
    #Story Intro
    input("Press Enter to start...\n")
    print("Congrats, Dr. " + name + "!")
    time.sleep(1)
    print(f"""You were hired by the CIA to work in {german_city}, Germany at the Der Riese top secret facility.
The facility was created by Dr. {german_name} after discovering the element 115 in a meteorite.
This element has interesting capabilites that seem to give extra strength to humans.
The team of scientists has already developed a mixture that limits pain and help faster recovery.
They named it the {strong_animal} soda.""")
    time.sleep(9)
          
    # Create a dashed line
    dashed_line = 0
    while dashed_line < 50:
        print('-', end="")# Print the dashes on the same line
        dashed_line += 1
        time.sleep(.03)
        
    time.sleep(1.5) 

    print("\nA few months into your new job, you're by yourself late at night working on your project...")
    time.sleep(2)

    # Start of the Game
    input("Suddenly, an alarm goes off! Press Enter to continue.\n")
    time.sleep(1.5)
          
    print("It's a code red!\n")
    time.sleep(1)
    
    # First choice
    print("What should you do?\n")
    time.sleep(1)
    
    #Options in the lab
    print("Press 1 to panic and run towards an exit.")
    print("Press 2 to take some time to explore your lab.")
          
    choice_1 = input("> ")
    
          
    # conditional input based on user input    
    if choice_1 == '1':
        fail_1()

    elif choice_1 == '2':
        explore() # this makes us explore our lab
    
    else:
        print("Invalid entry. Please try again.\n")
        lab() # Brings us back to the beginning of the lab to try again
    
          
#############################          
##Action in the first Room###       
#############################          
         
def explore():
    print("You decided to explore your lab...")
    time.sleep(.5)
     
    # Animation similar to a loading wheel while the user searches the lab
    searching = "/-\|" #animation to look like a laoding wheel
    print("Searching the lab:")
    for bars in range(20):
          time.sleep(0.2)
          sys.stdout.write("\r" + searching[bars % len(searching)])
          sys.stdout.flush() # remove what has been printed, to give room for the next part of the wheel

    print("You found a gas mask and knife.")
    time.sleep(1.5)
    print("After putting your gas mask on for safety, it's time to explore\n!")
    time.sleep(1.5)
    print("Where do you want to go?\n")
    time.sleep(1.5)
    
    #Three options from the first rooms
    print("Press 1 to go to the control room to have access to the cameras and security system.")
    print("Press 2 to look for the closest phone to call police.")
    print("Press 3 to go downstairs to the storage room for element 115.")
    
    choice = input("> ")
    
    if choice == '1':
        control_room() # This moves us into the control room

    elif choice == '2':
        fail_2() # This moves us into fail_2
        
    elif choice == '3':
        fail_3() # This moves us into fail_3
        
    
    else:
        print("Invalid entry. Please try again.\n")
        lab() # Brings us back to the beginning of the lab explore to try again
        
#####################################
## Second room: The Control Room ####    
#####################################    
    
def control_room():


    # list with all the text that will be displayed to the user      
    suspense_text = ["You've made it to the control room.",
                     "There is no one there.",
                     "You take a look at the surveillance screen but there's nothing out of the ordinary..",
                     "Wait..", 
                     "What is that in the storage room???", 
                     "It looks like some of your co-workers except...", 
                     "Except their face is falling apart", 
                     "They...", 
                     "They look like zombies...", 
                     "You panick and wonder how to escape.", 
                     "Especially, now that they were able to open the storage room and are starting to head towards the stairs!"
                    ]
    
    # for function with a time.sleep to display strings one by one and create suspense
    for text in suspense_text:
        print(text)
        time.sleep(1.3)
          
          
          
          
          
          
          
          
    input('Press Enter to continue\n')
    
    print(f"""You notice a {strong_animal} soda on a shelf.
    
It hasn't been tested yet but you know that there's a 70% chance that it will work.
If it works it could drastically improve your chances of survival
but if it doesn't you're not sure what would happen to you..""")
    
    
    
    choice_soda = input("Are you willing to take that risk?\nyes/no\n")
    
    if choice_soda == "yes":
        print("Let's see what happens!\n")
        time.sleep(1.5)
        random_number = random.randint(0,10) # generates a random number between 0-10
        
        if random_number <= 7: #if random number is lower than 7 the user survives
            print("Suddenly you feel a burst of energy in your body, the soda must have worked!\n")
            
        elif random_number >7:
            fail_4()
                  
        else:
            print("There was an error, try again")
            control_room() 
            
        
        
    elif choice_soda == "no":
        print("Let's hope the zombies are friendly..\n")
        
    else:
        print("Please write yes or no\n")
        choice_soda() # Send this user back to the beginning ot he room if the inout was incorrect
        

    
    
    
    
    print(f"""Should we run for our lives or try to get rid of these zombies?
We know that Dr.{german_name} is working on a top secret weapon in his lab
""")
    
    # Choices on where to go after the control room
    print("Press 1 for disabling the building security and running for your life.")
    print(f"Press 2 to go check Dr.{german_name}'s lab.")
    
    choice = input("> ")
    
    if choice == '1':
        fail_5() # Fail_5 scenario

    elif choice == '2':
        boss_lab() # This moves us the final room 
        
    
    else:
        print("Invalid entry. Please try again.\n")
        input('Press Enter to continue\n')
        
        control_room() # Brings us back to the beginning of the control room to try again

    
lab() # Calling the first function in our map will start our game

# %% [markdown]
# ***

# %%
#########################################################
# Adding richtofen_lab and linking it to the control_room
#########################################################



# Setup
#Import necessary packages
from sys import exit # check this one
import random
import time
import sys


#################################
# Def the Starting room function#
#################################

def lab():
    
    
    #Global variables that will be used in different rooms
    global name
    global german_city
    global strong_animal
    global german_name
    
    #Introduction
    print("""\nWelcome to Der Riese, the Game!
Before we start I need you to answer a few questions...""")
    
    #############
    #Questions##
    ############
    name = input("What is your last name?\n") #user input that will be used as the user's name
    name = name.capitalize() # capitalize first letter of user's input
    print(f"Welcome Dr.{name}!\n")
    time.sleep(.8) # creating a 0.8 seconde break
    
    german_city = input("What's your favorite german city? Feel free to make up a german city name if you can't think of one.\n ")
    german_city = german_city.capitalize() 
        
    strong_animal = input("What's the name of the strongest animal you can think of?\n")
    print("Interesting pick.. I have one more question.\n")
          
    german_name = input("Please make up a german sounding last name:\n")
    german_name = german_name.capitalize() # capitalize first letter of user's input
    print(f"{german_name}! That's a great name, but I'm glad it's not mine ;)\n")
    time.sleep(1)
          
    
    
    #Story Intro
    input("Press Enter to start...\n")
    print("Congrats, Dr. " + name + "!")
    time.sleep(1)
    print(f"""You were hired by the CIA to work in {german_city}, Germany at the Der Riese top secret facility.
The facility was created by Dr. {german_name} after discovering the element 115 in a meteorite.
This element has interesting capabilites that seem to give extra strength to humans.
The team of scientists has already developed a mixture that limits pain and help faster recovery.
They named it the {strong_animal} soda.""")
    time.sleep(9)
          
    # Create a dashed line
    dashed_line = 0
    while dashed_line < 50:
        print('-', end="")# Print the dashes on the same line
        dashed_line += 1
        time.sleep(.03)
        
    time.sleep(1.5) 

    print("\nA few months into your new job, you're by yourself late at night working on your project...")
    time.sleep(2)

    # Start of the Game
    input("Suddenly, an alarm goes off! Press Enter to continue.\n")
    time.sleep(1.5)
          
    print("It's a code red!\n")
    time.sleep(1)
    
    # First choice
    print("What should you do?\n")
    time.sleep(1)
    
    #Options in the lab
    print("Press 1 to panic and run towards an exit.")
    print("Press 2 to take some time to explore your lab.")
          
    choice_1 = input("> ")
    
          
    # conditional input based on user input    
    if choice_1 == '1':
        fail_1()

    elif choice_1 == '2':
        explore() # this makes us explore our lab
    
    else:
        print("Invalid entry. Please try again.\n")
        lab() # Brings us back to the beginning of the lab to try again
    
          
#############################          
##Action in the first Room###       
#############################          
         
def explore():
    print("You decided to explore your lab...")
    time.sleep(.5)
     
    # Animation similar to a loading wheel while the user searches the lab
    searching = "/-\|" #animation to look like a laoding wheel
    print("Searching the lab:")
    for bars in range(20):
          time.sleep(0.2)
          sys.stdout.write("\r" + searching[bars % len(searching)])
          sys.stdout.flush() # remove what has been printed, to give room for the next part of the wheel

    print("You found a gas mask and knife.")
    time.sleep(1.5)
    print("After putting your gas mask on for safety, it's time to explore\n!")
    time.sleep(1.5)
    print("Where do you want to go?\n")
    time.sleep(1.5)
    
    #Three options from the first rooms
    print("Press 1 to go to the control room to have access to the cameras and security system.")
    print("Press 2 to look for the closest phone to call police.")
    print("Press 3 to go downstairs to the storage room for element 115.")
    
    choice = input("> ")
    
    if choice == '1':
        control_room() # This moves us into the control room

    elif choice == '2':
        fail_2() # This moves us into fail_2
        
    elif choice == '3':
        fail_3() # This moves us into fail_3
        
    
    else:
        print("Invalid entry. Please try again.\n")
        lab() # Brings us back to the beginning of the lab explore to try again
        
#####################################
## Second room: The Control Room ####    
#####################################    
    
def control_room():


    # list with all the text that will be displayed to the user      
    suspense_text = ["You've made it to the control room.",
                     "There is no one there.",
                     "You take a look at the surveillance screen but there's nothing out of the ordinary..",
                     "Wait..", 
                     "What is that in the storage room???", 
                     "It looks like some of your co-workers except...", 
                     "Except their face is falling apart", 
                     "They...", 
                     "They look like zombies...", 
                     "You panick and wonder how to escape.", 
                     "Especially, now that they were able to open the storage room and are starting to head towards the stairs!"
                    ]
    
    # for function with a time.sleep to display strings one by one and create suspense
    for text in suspense_text:
        print(text)
        time.sleep(1.3)
          
          
          
          
          
          
          
          
    input('Press Enter to continue\n')
    
    print(f"""You notice a {strong_animal} soda on a shelf.
    
It hasn't been tested yet but you know that there's a 70% chance that it will work.
If it works it could drastically improve your chances of survival
but if it doesn't you're not sure what would happen to you..""")
    
    
    
    choice_soda = input("Are you willing to take that risk?\nyes/no\n")
    
    if choice_soda == "yes":
        print("Let's see what happens!\n")
        time.sleep(1.5)
        random_number = random.randint(0,10) # generates a random number between 0-10
        
        if random_number <= 7: #if random number is lower than 7 the user survives
            print("Suddenly you feel a burst of energy in your body, the soda must have worked!\n")
            
        elif random_number >7:
            fail_4()
                  
        else:
            print("There was an error, try again")
            control_room() 
            
        
        
    elif choice_soda == "no":
        print("Let's hope the zombies are friendly..\n")
        
    else:
        print("Please write yes or no\n")
        choice_soda() # Send this user back to the beginning ot he room if the inout was incorrect
        

    
    
    
    
    print(f"""Should we run for our lives or try to get rid of these zombies?
We know that Dr.{german_name} is working on a top secret weapon in his lab
""")
    
    # Choices on where to go after the control room
    print("Press 1 for disabling the building security and running for your life.")
    print(f"Press 2 to go check Dr.{german_name}'s lab.")
    
    choice = input("> ")
    
    if choice == '1':
        fail_5() # Fail_5 scenario

    elif choice == '2':
        boss_lab() # This moves us the final room 
        
    
    else:
        print("Invalid entry. Please try again.\n")
        input('Press Enter to continue\n')
        
        control_room() # Brings us back to the beginning of the control room to try again
        
        

######################        
### Final Room #######        
######################        

def boss_lab():
    print("""You're in the most secretive lab of the building. 
For the first time, you see a strange gun labeled Ray gun.

Are you ready to kill some zombies and save the lab?""")
    input("Press Enter if you are!\n")
    
    print("""You've arrived in at the top of the stairs and you're ready to fire your ray gun
press enter to shoot!""")
          
    zombies_left = 5
    # Interactive game where the user shoot at the zombies
    number_list = [1, 2, 3, 4, 5, 6, 7, 8, 9]

    while zombies_left > 2:   
    
        first_shot = random.choice(number_list)
    
        first_shot_user = input(f"To shoot, quickly enter {first_shot}!\n")
   
        first_shot_user = int(first_shot_user)

        if first_shot_user == first_shot:
            print("Nice aim you killed one of the zombie\n")
            zombies_left -= 1
            time.sleep(.8)
            print(f"There are {zombies_left} zombies left.\n")
    
        else:
            print("Unfortunately, you missed.. try again\n")
    
    if zombies_left == 2:
            print("The remaining zombies are aligned! Try to shoot them both at once")
            first_shot = random.choice(number_list)
            first_shot_user = input(f"To shoot, quickly enter {first_shot}!")
            first_shot_user = int(first_shot_user)
            
            if first_shot_user == first_shot:
                print("You aimed perfectly but the Ray Gun malfunctionned, Try again!")
                
            else: 
                print("Unfortunately, you miseed.. try again") 
                
            time.sleep(1)
            first_shot = random.choice(number_list)
            first_shot_user = input(f"To shoot, quickly enter {first_shot}!")
            first_shot_user = int(first_shot_user)
            if first_shot_user == first_shot:
                
                zombies_left -= 2
                print(f"\nCongrats Dr.{name} you killed all the zombies and contained the zombie invasion!")
        
                # Prompt the user if they want to play again or not
                replay()

lab() # Calling the first function in our map will start our game

# %% [markdown]
# ***
#
# <br>
#
# ## Part 2: Adding in a fail function and ways to fail

# %%
# Python 3
# Created by Alban de Raemy
# Hult International Business School - San Francisco
# Data Science: Python - MSBA 4
# due date: October 18th, 2020

"""
DocString:
    
    A) Introduction:
    This action text game ....
    
    
    
    B) Know Bugs and/or Errors:
    None.
    
"""
# Setup
#Import necessary packages
from sys import exit # check this one
import random
import time
import sys


#################################
# Def the Starting room function#
#################################

def lab():
    
    
    #Global variables that will be used in different rooms
    global name
    global german_city
    global strong_animal
    global german_name
    
    #Introduction
    print("""\nWelcome to Der Riese, the Game!
Before we start I need you to answer a few questions...""")
    
    #############
    #Questions##
    ############
    name = input("What is your last name?\n") #user input that will be used as the user's name
    name = name.capitalize() # capitalize first letter of user's input
    print(f"Welcome Dr.{name}!\n")
    time.sleep(.8) # creating a 0.8 seconde break
    
    german_city = input("What's your favorite german city? Feel free to make up a german city name if you can't think of one.\n ")
    german_city = german_city.capitalize() 
        
    strong_animal = input("What's the name of the strongest animal you can think of?\n")
    print("Interesting pick.. I have one more question.\n")
          
    german_name = input("Please make up a german sounding last name:\n")
    german_name = german_name.capitalize() # capitalize first letter of user's input
    print(f"{german_name}! That's a great name, but I'm glad it's not mine ;)\n")
    time.sleep(1)
          
    
    
    #Story Intro
    input("Press Enter to start...\n")
    print("Congrats, Dr. " + name + "!")
    time.sleep(1)
    print(f"""You were hired by the CIA to work in {german_city}, Germany at the Der Riese top secret facility.
The facility was created by Dr. {german_name} after discovering the element 115 in a meteorite.
This element has interesting capabilites that seem to give extra strength to humans.
The team of scientists has already developed a mixture that limits pain and help faster recovery.
They named it the {strong_animal} soda.""")
    time.sleep(9)
          
    # Create a dashed line
    dashed_line = 0
    while dashed_line < 50:
        print('-', end="")# Print the dashes on the same line
        dashed_line += 1
        time.sleep(.03)
        
    time.sleep(1.5) 

    print("\nA few months into your new job, you're by yourself late at night working on your project...")
    time.sleep(2)

    # Start of the Game
    input("Suddenly, an alarm goes off! Press Enter to continue.\n")
    time.sleep(1.5)
          
    print("It's a code red!\n")
    time.sleep(1)
    
    # First choice
    print("What should you do?\n")
    time.sleep(1)
    
    #Options in the lab
    print("Press 1 to panic and run towards an exit.")
    print("Press 2 to take some time to explore your lab.")
          
    choice_1 = input("> ")
    
          
    # conditional input based on user input    
    if choice_1 == '1':
        fail_1()

    elif choice_1 == '2':
        explore() # this makes us explore our lab
    
    else:
        print("Invalid entry. Please try again.\n")
        lab() # Brings us back to the beginning of the lab to try again

 
          
#############################          
##Action in the first Room###       
#############################          
         
def explore():
    print("You decided to explore your lab...")
    time.sleep(.5)
     
    # Animation similar to a loading wheel while the user searches the lab
    searching = "/-\|" #animation to look like a laoding wheel
    print("Searching the lab:")
    for bars in range(20):
          time.sleep(0.2)
          sys.stdout.write("\r" + searching[bars % len(searching)])
          sys.stdout.flush() # remove what has been printed, to give room for the next part of the wheel

    print("You found a gas mask and knife.")
    time.sleep(1.5)
    print("After putting your gas mask on for safety, it's time to explore\n!")
    time.sleep(1.5)
    print("Where do you want to go?\n")
    time.sleep(1.5)
    
    #Three options from the first rooms
    print("Press 1 to go to the control room to have access to the cameras and security system.")
    print("Press 2 to look for the closest phone to call police.")
    print("Press 3 to go downstairs to the storage room for element 115.")
    
    choice = input("> ")
    
    if choice == '1':
        control_room() # This moves us into the control room

    elif choice == '2':
        fail_2() # This moves us into fail_2
        
    elif choice == '3':
        fail_3() # This moves us into fail_3
        
    
    else:
        print("Invalid entry. Please try again.\n")
        lab() # Brings us back to the beginning of the lab explore to try again
    

#####################################
## Second room: The Control Room ####    
#####################################    
    
def control_room():


    # list with all the text that will be displayed to the user      
    suspense_text = ["You've made it to the control room.",
                     "There is no one there.",
                     "You take a look at the surveillance screen but there's nothing out of the ordinary..",
                     "Wait..", 
                     "What is that in the storage room???", 
                     "It looks like some of your co-workers except...", 
                     "Except their face is falling apart", 
                     "They...", 
                     "They look like zombies...", 
                     "You panick and wonder how to escape.", 
                     "Especially, now that they were able to open the storage room and are starting to head towards the stairs!"
                    ]
    
    # for function with a time.sleep to display strings one by one and create suspense
    for text in suspense_text:
        print(text)
        time.sleep(1.3)
          
          
          
          
          
          
          
          
    input('Press Enter to continue\n')
    
    print(f"""You notice a {strong_animal} soda on a shelf.
    
It hasn't been tested yet but you know that there's a 70% chance that it will work.
If it works it could drastically improve your chances of survival
but if it doesn't you're not sure what would happen to you..""")
    
    
    
    choice_soda = input("Are you willing to take that risk?\nyes/no\n")
    
    if choice_soda == "yes":
        print("Let's see what happens!\n")
        time.sleep(1.5)
        random_number = random.randint(0,10) # generates a random number between 0-10
        
        if random_number <= 7: #if random number is lower than 7 the user survives
            print("Suddenly you feel a burst of energy in your body, the soda must have worked!\n")
            
        elif random_number >7:
            fail_4()
                  
        else:
            print("There was an error, try again")
            control_room() 
            
        
        
    elif choice_soda == "no":
        print("Let's hope the zombies are friendly..\n")
        
    else:
        print("Please write yes or no\n")
        choice_soda() # Send this user back to the beginning ot he room if the inout was incorrect
        

    
    
    
    
    print(f"""Should we run for our lives or try to get rid of these zombies?
We know that Dr.{german_name} is working on a top secret weapon in his lab
""")
    
    # Choices on where to go after the control room
    print("Press 1 for disabling the building security and running for your life.")
    print(f"Press 2 to go check Dr.{german_name}'s lab.")
    
    choice = input("> ")
    
    if choice == '1':
        fail_5() # Fail_5 scenario

    elif choice == '2':
        boss_lab() # This moves us the final room 
        
    
    else:
        print("Invalid entry. Please try again.\n")
        input('Press Enter to continue\n')
        
        control_room() # Brings us back to the beginning of the control room to try again


        
        
######################        
### Final Room #######        
######################        

def boss_lab():
    print("""You're in the most secretive lab of the building. 
For the first time, you see a strange gun labeled Ray gun.

Are you ready to kill some zombies and save the lab?""")
    input("Press Enter if you are!\n")
    
    print("""You've arrived in at the top of the stairs and you're ready to fire your ray gun
press enter to shoot!""")
          
    zombies_left = 5
    # Interactive game where the user shoot at the zombies
    number_list = [1, 2, 3, 4, 5, 6, 7, 8, 9]

    while zombies_left > 2:   
    
        first_shot = random.choice(number_list)
    
        first_shot_user = input(f"To shoot, quickly enter {first_shot}!\n")
   
        first_shot_user = int(first_shot_user)

        if first_shot_user == first_shot:
            print("Nice aim you killed one of the zombie\n")
            zombies_left -= 1
            time.sleep(.8)
            print(f"There are {zombies_left} zombies left.\n")
    
        else:
            print("Unfortunately, you missed.. try again\n")
    
    if zombies_left == 2:
            print("The remaining zombies are aligned! Try to shoot them both at once")
            first_shot = random.choice(number_list)
            first_shot_user = input(f"To shoot, quickly enter {first_shot}!")
            first_shot_user = int(first_shot_user)
            
            if first_shot_user == first_shot:
                print("You aimed perfectly but the Ray Gun malfunctionned, Try again!")
                
            else: 
                print("Unfortunately, you miseed.. try again") 
                
            time.sleep(1)
            first_shot = random.choice(number_list)
            first_shot_user = input(f"To shoot, quickly enter {first_shot}!")
            first_shot_user = int(first_shot_user)
            if first_shot_user == first_shot:
                
                zombies_left -= 2
                print(f"\nCongrats Dr.{name} you killed all the zombies and contained the zombie invasion!")
        
                # Prompt the user if they want to play again or not
                replay()
          

    
                
                
    
#############################################################################
#### All possible ways to lose###############################################
#############################################################################


#Failure by not taking the necessary precautions (gas mask)
def fail_1():
    print("""After running towards the first exit,
you start to have trouble breathing and decide to rush back to your lab.
Unfortunately, as you are about to open the door you pass out due to the toxic
gases leaking from the element 115 storage room
""")
    time.sleep(1)
    print("GAME OVER")
    
    replay() 


def fail_2():
    print("You ran towards the closest phone only to discover that the line is not working.")
    time.sleep(1)
    print("You hear some weird noises...")
    time.sleep(1)
    print("You turn around and get attacked by a hoard of zombies...")
    time.sleep(1)
    print("GAME OVER")

    replay()

    
def fail_3():
    print("""You decide to go check the storage room, unfortunately while walking downstairs
you get trapped by a hoard of zombies emerging from the stoarge room of element 115.
""")
    time.sleep(1)
    print("GAME OVER")
    
    replay()

    
    
def fail_4():
    print(""""After a few sips, you start to feel bad...
Your skin becomes very itchy...
When you start to scratch your skin, you realize it's falling..
You became one of them!
""")
    time.sleep(1)
    print("GAME OVER")
    
    replay()
    
    
def fail_5():
    print("Congrats!! you escaped and saved your life!")
    time.sleep(1)
    print("But at what cost...")
    time.sleep(1)
    print("Now the zombies are free and are starting to attack the population..")
    time.sleep(1)
    print(f"The world will unfortunately remember the name {name}")
    time.sleep(1)
    print("GAME OVER")

    replay()
   
          
# replay function to use after each fail attempt and win
def replay():
    print("Would you like to play again?")
    replay = input("Type 'yes' or 'no'>")
          
    if replay == "yes":
        lab() #Goes back to the beginning of the game
    else:
        print(f"Thanks for playing Dr. {name} I hope you enjoyed this game")
        exit()
    
##############################################################################
####### GAME START ###########################################################
##############################################################################
lab()

# %% [markdown]
# ***
#
# <br>
#
# ## Part 3: Adding more functionality to the game
# Let's update our game as follows:
# * room_1
#     * nested conditional
# * room_2
# * room_3
#     * while loop
# * fail
#
# Our game map can be visualized as follows:
# <br><br>
#
# ~~~
#     room_1 <--> room_2 <--> room_3 (win)
#       *nc    |          |    *w
#               `----------`------> fail
# ~~~
#
# <br>

# %%
# Python 3
# Created by Alban de Raemy
# Hult International Business School - San Francisco
# Data Science: Python - MSBA 4
# due date: October 18th, 2020

"""
DocString:
    
    A) Introduction:
    This action text game puts you in the role of a scientist working in a top-secret facility. One day, an alarm goes off.
    The scientist needs to make a wise decision to survive and move from room to room until facing a surprise opponent.
    1. lab
    2. Control Room
    3. Dr. x's lab
    
    
    
    B) Know Bugs and/or Errors:
    None.
    
"""

# Setup
#Import necessary packages
from sys import exit # check this one
import random
import time
import sys


########################################
# Def the Starting room function - Lab #
########################################

def lab():
    
    
    #Global variables that will be used in different rooms
    global name
    global german_city
    global strong_animal
    global german_name
    
    #Introduction
    print("""\nWelcome to Der Riese, the Game!
Before we start I need you to answer a few questions...""")
    
    #############
    #Questions##
    ############
    name = input("What is your last name?\n") #user input that will be used as the user's name
    name = name.capitalize() # capitalize first letter of user's input
    print(f"Welcome Dr.{name}!\n")
    time.sleep(.8) # creating a 0.8 seconde break
    
    german_city = input("What's your favorite german city? Feel free to make up a german city name if you can't think of one.\n ")
    german_city = german_city.capitalize() 
        
    strong_animal = input("What's the name of the strongest animal you can think of?\n")
    print("Interesting pick.. I have one more question.\n")
          
    german_name = input("Please make up a german sounding last name:\n")
    german_name = german_name.capitalize() # capitalize first letter of user's input
    print(f"{german_name}! That's a great name, but I'm glad it's not mine ;)\n")
    time.sleep(1)
          
    
    
    #Story Intro
    input("Press Enter to start...\n")
    print("Congrats, Dr. " + name + "!") #the variable name is from the user's previous input
    time.sleep(1)
    print(f"""You were hired by the CIA to work in {german_city}, Germany at the Der Riese top secret facility.
The facility was created by Dr. {german_name} after discovering the element 115 in a meteorite.
This element has interesting capabilites that seem to give extra strength to humans.
The team of scientists has already developed a mixture that limits pain and help faster recovery.
They named it the {strong_animal} soda.""") #some aspect of the story are personalized by the user
    time.sleep(9) # give a good amount of time for the user to read the text
          
    # Create a dashed line
    dashed_line = 0
    while dashed_line < 50:
        print('-', end="")# Print the dashes on the same line
        dashed_line += 1
        time.sleep(.03)
        
    time.sleep(1.5) 

    print("\nA few months into your new job, you're by yourself late at night working on your project...")
    time.sleep(1.5)

    # Start of the Game
    input("Suddenly, an alarm goes off! Press Enter to continue.\n")
    time.sleep(1.5)
          
    print("It's a code red!\n")
    time.sleep(1)
    
    # First choice
    print("What should you do?\n")
    time.sleep(1)
    
    #Options in the lab
    print("Press 1 to panic and run towards an exit.")
    print("Press 2 to take some time to explore your lab.")
          
    choice_1 = input("> ")
    
          
    # conditional input based on user input    
    if choice_1 == '1':
        fail_1()

    elif choice_1 == '2':
        explore() # this makes us explore our lab
    
    else:
        print("Invalid entry. Please try again.\n")
        lab() # Brings us back to the beginning of the lab to try again

 
          
#############################          
##Action in the first Room###       
#############################          
         
def explore():
    print("You decided to explore your lab...")
    time.sleep(.5)
     
    # Animation similar to a loading wheel while the user searches the lab
    searching = "/-\|" #animation to look like a laoding wheel
    print("Searching the lab:")
    for bars in range(20):
          time.sleep(0.2)
          sys.stdout.write("\r" + searching[bars % len(searching)])
          sys.stdout.flush() # remove what has been printed, to give room for the next part of the wheel

    print("You found a gas mask and knife.")
    time.sleep(1.5)
    print("After putting your gas mask on for safety, it's time to explore!\n")
    time.sleep(1.5)
    print("Where do you want to go?\n")
    time.sleep(1.5)
    
    #Three options from the first rooms
    print("Press 1 to go to the control room to have access to the cameras and security system.")
    print("Press 2 to look for the closest phone to call police.")
    print("Press 3 to go downstairs to the storage room for element 115.")
    
    choice = input("> ")
    
    if choice == '1':
        control_room() # This moves us into the control room

    elif choice == '2':
        fail_2() # This moves us into fail_2
        
    elif choice == '3':
        fail_3() # This moves us into fail_3
        
    
    else:
        print("Invalid entry. Please try again.\n")
        explore() # Brings us back to the beginning of lab explore to try again
    

#####################################
## Second room: The Control Room ####    
#####################################    
    
def control_room():


    # list with all the text that will be displayed to the user      
    suspense_text = ["You've made it to the control room.",
                     "There is no one there.",
                     "You take a look at the surveillance screen but there's nothing out of the ordinary..",
                     "Wait..", 
                     "What is that in the storage room???", 
                     "It looks like some of your co-workers except...", 
                     "Except their face is falling apart", 
                     "They...", 
                     "They look like zombies...", 
                     "You panick and wonder how to escape.", 
                     "Especially, now that they were able to open the storage room and are starting to head towards the stairs!"
                    ]
    
    # for function with a time.sleep to display strings one by one and create suspense
    for text in suspense_text:
        print(text)
        time.sleep(1.3)
          
          
          
          
          
          
          
    # making sure the user is still engaged      
    input('Press Enter to continue\n')
    
    print(f"""You notice a {strong_animal} soda on a shelf.
    
It hasn't been tested yet but you know that there's a 70% chance that it will work.
If it works it could drastically improve your chances of survival
but if it doesn't you're not sure what would happen to you..""")
    
    
    
    choice_soda = input("Are you willing to take that risk?\nyes/no\n")
    # the soda has a high chance of helping you but could also kill you
    if choice_soda == "yes":
        print("Let's see what happens!\n")
        time.sleep(1.5)
        random_number = random.randint(0,10) # generates a random number between 0-10
        
        if random_number <= 7: #if random number is lower than 7 the user survives
            print("Suddenly you feel a burst of energy in your body, the soda must have worked!\n")
            
        elif random_number >7:
            fail_4()
                  
        else:
            print("There was an error, try again")
            control_room() 
            
        
        
    elif choice_soda == "no":
        print("Let's hope the zombies are friendly..\n")
        
    else:
        print("Please write yes or no\n")
        choice_soda() # Send this user back to the beginning ot he room if the inout was incorrect
        

    
    
    
    # hint that the user should go explore the Dr. Lab
    print(f"""Should we run for our lives or try to get rid of these zombies?
We know that Dr.{german_name} is working on a top secret weapon in his lab
""")
    
    # Choices on where to go after the control room
    print("Press 1 for disabling the building security and running for your life.")
    print(f"Press 2 to go check Dr.{german_name}'s lab.")
    
    choice = input("> ")
    
    if choice == '1':
        fail_5() # Fail_5 scenario

    elif choice == '2':
        boss_lab() # This moves us the final room 
        
    
    else:
        print("Invalid entry. Please try again.\n")
        input('Press Enter to continue\n')
        
        control_room() # Brings us back to the beginning of the control room to try again


        
        
######################        
### Final Room #######        
######################        

def boss_lab():
    print("""You're in the most secretive lab of the building. 
For the first time, you see a strange gun labeled Ray gun.

Are you ready to kill some zombies and save the lab?""")
    input("Press Enter if you are!\n")
    
    print("""You've arrived in at the top of the stairs and you're ready to fire your ray gun
press enter to shoot!""")
          
    zombies_left = 5 # count of the number of zombies left 
    # Interactive game where the user shoot at the zombies
    number_list = [1, 2, 3, 4, 5, 6, 7, 8, 9]

    while zombies_left > 2:   
    
        first_shot = random.choice(number_list) #takes a random number from the list
    
        first_shot_user = input(f"To shoot, quickly enter {first_shot}!\n") # ask for user to enter the randomly selected number
   
        first_shot_user = int(first_shot_user) # convert the string to an int

        if first_shot_user == first_shot: #compares the randomly selected number with the user's input
            print("Nice aim you killed one of the zombie\n") # if the user typed the correct number he kills a zombie
            zombies_left -= 1 # reduces the toatl number of zombies
            time.sleep(.8)
            print(f"There are {zombies_left} zombies left.\n")
    
        else:
            print("Unfortunately, you missed.. try again\n")
    
    if zombies_left == 2:
            # same mechanisim as before
            print("The remaining zombies are aligned! Try to shoot them both at once")
            first_shot = random.choice(number_list)
            first_shot_user = input(f"To shoot, quickly enter {first_shot}!")
            first_shot_user = int(first_shot_user)
            
            # gun malfunction 
            if first_shot_user == first_shot:
                print("You aimed perfectly but the Ray Gun malfunctionned, Try again!")
                
            else: 
                print("Unfortunately, you miseed.. try again") 
                
            time.sleep(1)
            first_shot = random.choice(number_list)
            first_shot_user = input(f"To shoot, quickly enter {first_shot}!")
            first_shot_user = int(first_shot_user)
            if first_shot_user == first_shot:
                
                # the user wins!
                zombies_left -= 2
                print(f"\nCongrats Dr. {name} you killed all the zombies and contained the zombie invasion!")
        
                # Prompt the user if they want to play again or not
                replay()
          

    
                
                
    
#############################################################################
#### All possible ways to lose###############################################
#############################################################################


#Failure by not taking the necessary precautions (gas mask)
def fail_1():
    print("""After running towards the first exit,
you start to have trouble breathing and decide to rush back to your lab.
Unfortunately, as you are about to open the door you pass out due to the toxic
gases leaking from the element 115 storage room
""")
    time.sleep(1)
    print("GAME OVER")
    
    replay() 

# Failure to notice the zombies 
def fail_2():
    print("You ran towards the closest phone only to discover that the line is not working.")
    time.sleep(1)
    print("You hear some weird noises...")
    time.sleep(1)
    print("You turn around and get attacked by a hoard of zombies...")
    time.sleep(1)
    print("GAME OVER")

    replay()

# Failure to notice the zombies while going to the storage room
def fail_3():
    print("""You decide to go check the storage room, unfortunately while walking downstairs
you get trapped by a hoard of zombies emerging from the stoarge room of element 115.
""")
    time.sleep(1)
    print("GAME OVER")
    
    replay()

    
# Unfortunately, the users dies due to a faulty x soda    
def fail_4():
    print(""""After a few sips, you start to feel bad...
Your skin becomes very itchy...
When you start to scratch your skin, you realize it's falling..
You became one of them!
""")
    time.sleep(1)
    print("GAME OVER")
    
    replay()
    
# The user is alive but loses the game due to freeing the zombies but mistake    
def fail_5():
    print("Congrats!! you escaped and saved your life!")
    time.sleep(1)
    print("But at what cost...")
    time.sleep(1)
    print("Now the zombies are free and are starting to attack the population..")
    time.sleep(1)
    print(f"The world will unfortunately remember the name {name}")
    time.sleep(1)
    print("GAME OVER")

    replay()
   
          
# replay function to use after each fail attempt and win
def replay():
    print("Would you like to play again?")
    replay = input("Type 'yes' or 'no'>")
          
    if replay == "yes":
        lab() #Goes back to the beginning of the game
    else:
        print(f"Thanks for playing Dr. {name} I hope you enjoyed this game")
        exit()
    
##############################################################################
####### GAME START ###########################################################
##############################################################################
lab()
# Out:
# Welcome to Der Riese, the Game!
# Before we start I need you to answer a few questions...

# %% [markdown]
# <br>
